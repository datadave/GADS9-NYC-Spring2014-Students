# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dates = pd.date_range('20140105',periods=7) 
#created a dataframe of 7 dates from 20140105

# %%
df = pd.DataFrame(np.random.randn(7,5),index=dates,columns=list('ABCDE')) 
#put random numbers in 7 rows & 5 columns and make the columns titled ABCDE

# %%
df #prints a matrix of the dataset
# Out:
#                    A         B         C         D         E
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 -0.322743
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402  0.547050
# 2014-01-09 -0.590224 -1.682659 -0.853011 -1.168056 -0.054169
# 2014-01-10  1.861882 -1.322720 -0.402930 -1.037427  0.305018
# 2014-01-11  2.235864 -1.014136  1.341677 -1.186987 -1.518220
#
# [7 rows x 5 columns]

# %%
df2 = pd.DataFrame({ 'A' : 1.,
                    'B' : pd.Timestamp('20130102'),
                    'C' : pd.Series(1,index=list(range(4)),dtype='float32'),
                    'D' : np.array([3] * 4,dtype='int32'),
                    'E' : 'wtf'})

#This is creating a new dataset. Column by column, telling what to put in them
#Note, that there is a reference column

# %%
df2
# Out:
#    A          B  C  D    E
# 0  1 2013-01-02  1  3  wtf
# 1  1 2013-01-02  1  3  wtf
# 2  1 2013-01-02  1  3  wtf
# 3  1 2013-01-02  1  3  wtf
#
# [4 rows x 5 columns]

# %%
df2.dtypes #gives the data types that are in the columns
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E            object
# dtype: object

# %%
df.head() #shows the top 5 rows
# Out:
#                    A         B         C         D         E
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 -0.322743
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402  0.547050
# 2014-01-09 -0.590224 -1.682659 -0.853011 -1.168056 -0.054169
#
# [5 rows x 5 columns]

# %%
df.index #gives basic information about the dataset
# Out:
# <class 'pandas.tseries.index.DatetimeIndex'>
# [2014-01-05, ..., 2014-01-11]
# Length: 7, Freq: D, Timezone: None

# %%
df.describe()
# Out:
#               A         B         C         D         E
# count  7.000000  7.000000  7.000000  7.000000  7.000000
# mean   0.908392 -0.168659  0.044319 -1.200880 -0.071645
# std    1.089851  1.279369  0.742624  0.729499  0.748944
# min   -0.590224 -1.682659 -0.853011 -2.480836 -1.518220
# 25%    0.036580 -1.168428 -0.470344 -1.451498 -0.263264
# 50%    1.066387 -0.099079 -0.033637 -1.168056 -0.054169
# 75%    1.786780  0.677805  0.397946 -0.748914  0.426034
# max    2.235864  1.582370  1.341677 -0.356444  0.745332
#
# [8 rows x 5 columns]

# %%
df.sort(columns='B') #sorts the entire datafram by columnB in ascending order
# Out:
#                    A         B         C         D         E
# 2014-01-09 -0.590224 -1.682659 -0.853011 -1.168056 -0.054169
# 2014-01-10  1.861882 -1.322720 -0.402930 -1.037427  0.305018
# 2014-01-11  2.235864 -1.014136  1.341677 -1.186987 -1.518220
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 -0.322743
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402  0.547050
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
#
# [7 rows x 5 columns]

# %%
df['A'] #only spits out column A
# Out:
# 2014-01-05   -0.061218
# 2014-01-06    1.711678
# 2014-01-07    1.066387
# 2014-01-08    0.134378
# 2014-01-09   -0.590224
# 2014-01-10    1.861882
# 2014-01-11    2.235864
# Freq: D, Name: A, dtype: float64

# %%
df[0:3] #spits out only rows 0-2 ..3 rows
# Out:
#                    A         B         C         D         E
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 -0.322743
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
#
# [3 rows x 5 columns]

# %%
df.loc[dates[0]] #not sure why, but its giving the values of row 3
# Out:
# A   -0.061218
# B   -0.099079
# C   -0.033637
# D   -2.480836
# E   -0.322743
# Name: 2014-01-05 00:00:00, dtype: float64

# %%
df.loc[:,['A','B']] #specific columns, all rows
# Out:
#                    A         B
# 2014-01-05 -0.061218 -0.099079
# 2014-01-06  1.711678  1.582370
# 2014-01-07  1.066387 -0.021436
# 2014-01-08  0.134378  1.377047
# 2014-01-09 -0.590224 -1.682659
# 2014-01-10  1.861882 -1.322720
# 2014-01-11  2.235864 -1.014136
#
# [7 rows x 2 columns]

# %%
df.loc['20140106':'20140109',['B']] #specific row range and column
# Out:
#                    B
# 2014-01-06  1.582370
# 2014-01-07 -0.021436
# 2014-01-08  1.377047
# 2014-01-09 -1.682659
#
# [4 rows x 1 columns]

# %%
df.at[dates[1],'D']
# Out:
# -0.35644368701726498

# %%
df[df.A < 0] #returns rows where A is <0
# Out:
#                    A         B         C         D         E
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 -0.322743
# 2014-01-09 -0.590224 -1.682659 -0.853011 -1.168056 -0.054169
#
# [2 rows x 5 columns]

# %%
df_posA = df.copy() # we are making a copy of the datasest to use
df_posA #prints a duplicate copy of df
# Out:
#                    A         B         C         D         E
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 -0.322743
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402  0.547050
# 2014-01-09 -0.590224 -1.682659 -0.853011 -1.168056 -0.054169
# 2014-01-10  1.861882 -1.322720 -0.402930 -1.037427  0.305018
# 2014-01-11  2.235864 -1.014136  1.341677 -1.186987 -1.518220
#
# [7 rows x 5 columns]

# %%
df_posA[df_posA.A<0] = -1*df_posA #so where A<0, multiply the row by -1
df_posA #returns with column A all pos, row 0 and 4 reversed
# Out:
#                    A         B         C         D         E
# 2014-01-05  0.061218  0.099079  0.033637  2.480836  0.322743
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402  0.547050
# 2014-01-09  0.590224  1.682659  0.853011  1.168056  0.054169
# 2014-01-10  1.861882 -1.322720 -0.402930 -1.037427  0.305018
# 2014-01-11  2.235864 -1.014136  1.341677 -1.186987 -1.518220
#
# [7 rows x 5 columns]

# %%
df_posA
# Out:
#                    A         B         C         D         E
# 2014-01-05  0.061218  0.099079  0.033637  2.480836  0.322743
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 -0.203785
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009  0.745332
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402  0.547050
# 2014-01-09  0.590224  1.682659  0.853011  1.168056  0.054169
# 2014-01-10  1.861882 -1.322720 -0.402930 -1.037427  0.305018
# 2014-01-11  2.235864 -1.014136  1.341677 -1.186987 -1.518220
#
# [7 rows x 5 columns]

# %%
s2 = pd.Series([1,2,3,4,5,6,7],index=pd.date_range('20140105',periods=7))
s2
# Out:
# 2014-01-05    1
# 2014-01-06    2
# 2014-01-07    3
# 2014-01-08    4
# 2014-01-09    5
# 2014-01-10    6
# 2014-01-11    7
# Freq: D, dtype: int64

# %%
df['G'] = s2
df
# Out:
#                    A         B         C         D   E   F  G   H
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 NaN NaN  1 NaN
# 2014-01-06  1.711678  1.582370  0.511030 -0.356444 NaN NaN  2 NaN
# 2014-01-07  1.066387 -0.021436  0.284862 -1.716009 NaN NaN  3 NaN
# 2014-01-08  0.134378  1.377047 -0.537759 -0.460402 NaN NaN  4 NaN
# 2014-01-09 -0.590224 -1.682659 -0.853011 -1.168056 NaN NaN  5 NaN
# 2014-01-10  1.861882 -1.322720 -0.402930 -1.037427 NaN NaN  6 NaN
# 2014-01-11  2.235864 -1.014136  1.341677 -1.186987 NaN NaN  7 NaN
#
# [7 rows x 8 columns]

# %%
#Idont know what Im doing wrong

# %%
df.describe()
# Out:
#               A         B         C         D         E
# count  7.000000  7.000000  7.000000  7.000000  7.000000
# mean  -0.623520 -0.836717  0.496527 -0.327825 -0.087917
# std    0.675252  0.698327  0.754294  1.647384  1.151722
# min   -1.679198 -1.793296 -0.984365 -3.694070 -1.397411
# 25%   -0.976365 -1.223256  0.345435 -0.375829 -0.776528
# 50%   -0.626097 -0.970706  0.590713 -0.102838 -0.148369
# 75%   -0.157878 -0.504578  0.883143  0.303061  0.149074
# max    0.209137  0.362653  1.412187  1.647672  2.185267
#
# [8 rows x 5 columns]

# %%
df.mean(),df.mean(1)
# Out:
# (A   -0.623520
# B   -0.836717
# C    0.496527
# D   -0.327825
# E   -0.087917
# dtype: float64,
#  2014-01-05    0.315605
# 2014-01-06   -0.950230
# 2014-01-07   -0.503729
# 2014-01-08    0.061336
# 2014-01-09   -0.107185
# 2014-01-10    0.043584
# 2014-01-11   -0.790611
# Freq: D, dtype: float64)

# %%
df.apply(np.cumsum)
# Out:
#                    A         B         C         D   E   F   G   H
# 2014-01-05 -0.061218 -0.099079 -0.033637 -2.480836 NaN NaN   1 NaN
# 2014-01-06  1.650460  1.483291  0.477393 -2.837280 NaN NaN   3 NaN
# 2014-01-07  2.716847  1.461855  0.762254 -4.553288 NaN NaN   6 NaN
# 2014-01-08  2.851226  2.838901  0.224495 -5.013690 NaN NaN  10 NaN
# 2014-01-09  2.261001  1.156242 -0.628516 -6.181746 NaN NaN  15 NaN
# 2014-01-10  4.122884 -0.166478 -1.031446 -7.219173 NaN NaN  21 NaN
# 2014-01-11  6.358747 -1.180614  0.310231 -8.406160 NaN NaN  28 NaN
#
# [7 rows x 8 columns]

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    2.826088
# B    3.265029
# C    2.194688
# D    2.124392
# E         NaN
# F         NaN
# G    6.000000
# H         NaN
# dtype: float64

# %%
#What is this??

# %%
s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat']) 
s.str.lower() #makes it all lower case
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
np.random.randn(10,4)
# Out:
# array([[-0.53439056, -1.28672203,  0.30730939,  0.24864931],
#        [-0.49784069,  0.88824903, -0.35692348, -0.54492787],
#        [-0.15167421,  1.20631621,  0.83755544, -0.48086455],
#        [-0.23053048, -0.7967048 , -0.49647482,  0.88376918],
#        [-0.23305042,  1.58854988, -0.276325  ,  1.09162568],
#        [ 0.06365297,  0.83146164,  1.28253783, -0.39166476],
#        [ 0.54342269,  0.59653799, -1.81018224,  0.37723654],
#        [-0.07621719,  1.40893804,  0.90324927,  1.65537112],
#        [ 0.4774106 , -0.15017823,  1.28793204, -0.03939145],
#        [-0.74628635, -1.12634747, -0.69467584, -0.21387452]])

# %%
df = pd.DataFrame(np.random.randn(10,4))
df
# Out:
#           0         1         2         3
# 0  0.919736 -1.273239 -2.167695  0.845433
# 1 -1.993610  0.310016 -0.148582 -0.088398
# 2 -2.343621 -1.875493  0.896538  0.267637
# 3 -0.774798  1.060898  0.930041 -0.854346
# 4  0.873963  0.572289  0.670970 -1.850728
# 5 -0.808950 -1.374328  0.715572  0.471646
# 6  1.275485  0.128739 -0.572627 -0.410420
# 7  1.205699  0.440167  1.171597  2.073287
# 8 -0.896551 -0.690766 -1.346378 -0.638086
# 9  0.032986  1.375913  0.019378 -1.202593
#
# [10 rows x 4 columns]

# %%
pieces = [df[:3], df[3:7],df[7:]]
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.919736 -1.273239 -2.167695  0.845433
# 1 -1.993610  0.310016 -0.148582 -0.088398
# 2 -2.343621 -1.875493  0.896538  0.267637
# 3 -0.774798  1.060898  0.930041 -0.854346
# 4  0.873963  0.572289  0.670970 -1.850728
# 5 -0.808950 -1.374328  0.715572  0.471646
# 6  1.275485  0.128739 -0.572627 -0.410420
# 7  1.205699  0.440167  1.171597  2.073287
# 8 -0.896551 -0.690766 -1.346378 -0.638086
# 9  0.032986  1.375913  0.019378 -1.202593
#
# [10 rows x 4 columns]

# %%
#what is concatenating?

# %%
df = pd.DataFrame({'A' : ['foo', 'bar','foo', 'bar','foo', 'bar','foo', 'foo'],
                   'B' : ['one', 'one', 'two', 'three', 'two', 'two', 'one', 'three'],
                   'C' : np.random.randn(8),
                   'D' : np.random.randn(8)})

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  0.243697  0.388402
# 1  bar    one  0.251545  0.779305
# 2  foo    two -0.235747  0.389080
# 3  bar  three -0.297730 -0.430977
# 4  foo    two  0.215113 -0.190449
# 5  bar    two  0.363504 -0.021971
# 6  foo    one  1.142238 -2.270470
# 7  foo  three  1.753561  0.217831
#
# [8 rows x 4 columns]

# %%
df.groupby(['A','B']).sum() #data sorted & grouped by A and then B, sumed
#note the resulting foo one is the sum of the two rows above w.combo
# Out:
#                   C         D
# A   B
# bar one    0.251545  0.779305
#     three -0.297730 -0.430977
#     two    0.363504 -0.021971
# foo one    1.385935 -1.882068
#     three  1.753561  0.217831
#     two   -0.020634  0.198631
#
# [6 rows x 2 columns]

# %%
pd.pivot_table(df, values=['C','D'],rows=['A'],cols=['B'])
# Out:
#             C                             D
# B         one     three       two       one     three       two
# A
# bar  0.251545 -0.297730  0.363504  0.779305 -0.430977 -0.021971
# foo  0.692968  1.753561 -0.010317 -0.941034  0.217831  0.099315
#
# [2 rows x 6 columns]

# %%
#TIME SERIES

# %%
rng = pd.date_range('1/1/2014', periods=100, freq='S') 
#grabs a 100 seconds starting from date 1/1/14, 1min 40 sec
ts = pd.Series(np.random.randint(0,500,len(rng)), index=rng)
#gives each sec a random value btwn 0 and 500
ts
# Out:
# 2014-01-01 00:00:00    148
# 2014-01-01 00:00:01    185
# 2014-01-01 00:00:02    118
# 2014-01-01 00:00:03     41
# 2014-01-01 00:00:04    314
# 2014-01-01 00:00:05    203
# 2014-01-01 00:00:06    300
# 2014-01-01 00:00:07    140
# 2014-01-01 00:00:08    229
# 2014-01-01 00:00:09    281
# 2014-01-01 00:00:10    409
# 2014-01-01 00:00:11    191
# 2014-01-01 00:00:12     31
# 2014-01-01 00:00:13    431
# 2014-01-01 00:00:14    497
# ...
# 2014-01-01 00:01:25    366
# 2014-01-01 00:01:26    111
# 2014-01-01 00:01:27    296
# 2014-01-01 00:01:28    440
# 2014-01-01 00:01:29    116
# 2014-01-01 00:01:30    168
# 2014-01-01 00:01:31    395
# 2014-01-01 00:01:32    364
# 2014-01-01 00:01:33    397
# 2014-01-01 00:01:34    419
# 2014-01-01 00:01:35     31
# 2014-01-01 00:01:36    294
# 2014-01-01 00:01:37    319
# 2014-01-01 00:01:38    340
# 2014-01-01 00:01:39    151
# Freq: S, Length: 100

# %%
ts.resample('1Min',how='mean')
# Out:
# 2014-01-01 00:00:00    238.416667
# 2014-01-01 00:01:00    278.475000
# Freq: T, dtype: float64

# %%
#not sure what resampling here is?

# %%
#PLOTTING

# %%
ts.plot()
def randwalk(startdate,points):
    ts = pd.Series(np.random.randn(points), index=pd.date_range(startdate, periods=points))
    ts=ts.cumsum()
    ts.plot()
    return(ts)

# %%
a=randwalk('1/1/2012',1000)

# %%
df = pd.DataFrame(np.random.randn(100,4), index=ts.index,columns=['A','B','C', 'D'])
df = df.cumsum()
plt.figure();df.plot();plt.legend(loc='best')

# %%
#Am I supposed to see something??
