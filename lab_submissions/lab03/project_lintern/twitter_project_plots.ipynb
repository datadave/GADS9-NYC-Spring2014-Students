# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.tools.plotting import scatter_matrix

data = pd.read_csv('twitter_FINAL.csv')
length = len(data)

#105 unique countries



#typ =data.COUNTRY.unique()
len(typ)


country_ct=(data.groupby(data.COUNTRY).count())
#countries with mas
#max_country=country_ct.sort('COUNTRY').count()
#print max_country.tail(5)

#Create Bar Graphs : Country vs. Count
#country_ct.COUNTRY.plot(kind='bar',title='Who is Talking about Crimea?',figsize = (17,7))

#clean up timestamp:
clean_time=[str(r.split('::')[0])for r in data.TIMESTAMP]

length = len(clean_time)


float_lt=[]
i=0
while i < length:
    new_time=float(clean_time[i])
    float_lt.append(new_time)
    i +=1
#print float_lt



#find timesteps for tweets
delta_lt=[]
ii=0
while ii < (length-1):
    delta=(float_lt[ii+1]-float_lt[ii])
    delta_lt.append(delta)
    ii +=1

# timespan bet 1st and last tweet?   ~   (approx. 1.7 hours)
#time = (float_lt[895]-float_lt[0])/3600


plt.scatter(data.LONG, data.LAT?
