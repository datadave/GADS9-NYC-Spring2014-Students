# %%
import pandas as pd
import numpy as np
import os

data = pd.read_csv(os.path.join('https://raw.github.com/pydata/pandas/master/pandas/tests/data/iris.csv'))

# %%
grouped = data.groupby('Name')
len(grouped)
# Out:
# 3

# %%
len(np.unique(data['Name']))
# Out:
# 3

# %%
print len(data[data['Name'] == 'Iris-setosa'])
print len(data[data['Name'] == 'Iris-versicolor'])
print len(data[data['Name'] == 'Iris-virginica'])
# Out:
# 50
# 50
# 50

# %%
grouped.describe()
# Out:
#                        SepalLength  SepalWidth  PetalLength  PetalWidth
# Name
# Iris-setosa     count    50.000000   50.000000    50.000000   50.000000
#                 mean      5.006000    3.418000     1.464000    0.244000
#                 std       0.352490    0.381024     0.173511    0.107210
#                 min       4.300000    2.300000     1.000000    0.100000
#                 25%       4.800000    3.125000     1.400000    0.200000
#                 50%       5.000000    3.400000     1.500000    0.200000
#                 75%       5.200000    3.675000     1.575000    0.300000
#                 max       5.800000    4.400000     1.900000    0.600000
# Iris-versicolor count    50.000000   50.000000    50.000000   50.000000
#                 mean      5.936000    2.770000     4.260000    1.326000
#                 std       0.516171    0.313798     0.469911    0.197753
#                 min       4.900000    2.000000     3.000000    1.000000
# ...

# %%
data.min()
# Out:
# SepalLength            4.3
# SepalWidth             2.0
# PetalLength            1.0
# PetalWidth             0.1
# Name           Iris-setosa
# dtype: object

# %%
data.max()
# Out:
# SepalLength               7.9
# SepalWidth                4.4
# PetalLength               6.9
# PetalWidth                2.5
# Name           Iris-virginica
# dtype: object

# %%
data.median()
# Out:
# SepalLength    5.80
# SepalWidth     3.00
# PetalLength    4.35
# PetalWidth     1.30
# dtype: float64

# %%
data.mean()
# Out:
# SepalLength    5.843333
# SepalWidth     3.054000
# PetalLength    3.758667
# PetalWidth     1.198667
# dtype: float64

# %%
setosa = data[data['Name'] == 'Iris-setosa']
print setosa.min()
print setosa.median()
print setosa.mean()
print setosa.max()
# Out:
# SepalLength            4.3
# SepalWidth             2.3
# PetalLength            1.0
# PetalWidth             0.1
# Name           Iris-setosa
# dtype: object
# SepalLength    5.0
# SepalWidth     3.4
# PetalLength    1.5
# PetalWidth     0.2
# dtype: float64
# SepalLength    5.006
# SepalWidth     3.418
# PetalLength    1.464
# PetalWidth     0.244
# dtype: float64
# SepalLength            5.8
# SepalWidth             4.4
# PetalLength            1.9
# PetalWidth             0.6
# Name           Iris-setosa
# dtype: object

# %%
versicolor = data[data['Name'] == 'Iris-versicolor']
print versicolor.min()
print versicolor.median()
print versicolor.mean()
print versicolor.max()
# Out:
# SepalLength                4.9
# SepalWidth                 2.0
# PetalLength                3.0
# PetalWidth                 1.0
# Name           Iris-versicolor
# dtype: object
# SepalLength    5.90
# SepalWidth     2.80
# PetalLength    4.35
# PetalWidth     1.30
# dtype: float64
# SepalLength    5.936
# SepalWidth     2.770
# PetalLength    4.260
# PetalWidth     1.326
# dtype: float64
# SepalLength                7.0
# SepalWidth                 3.4
# PetalLength                5.1
# PetalWidth                 1.8
# Name           Iris-versicolor
# dtype: object

# %%
virginica = data[data['Name'] == 'Iris-virginica']
print virginica.min()
print virginica.median()
print virginica.mean()
print virginica.max()
# Out:
# SepalLength               4.9
# SepalWidth                2.2
# PetalLength               4.5
# PetalWidth                1.4
# Name           Iris-virginica
# dtype: object
# SepalLength    6.50
# SepalWidth     3.00
# PetalLength    5.55
# PetalWidth     2.00
# dtype: float64
# SepalLength    6.588
# SepalWidth     2.974
# PetalLength    5.552
# PetalWidth     2.026
# dtype: float64
# SepalLength               7.9
# SepalWidth                3.8
# PetalLength               6.9
# PetalWidth                2.5
# Name           Iris-virginica
# dtype: object

# %%
print data.sort(columns='SepalLength')
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 13           4.3         3.0          1.1         0.1      Iris-setosa
# 42           4.4         3.2          1.3         0.2      Iris-setosa
# 38           4.4         3.0          1.3         0.2      Iris-setosa
# 8            4.4         2.9          1.4         0.2      Iris-setosa
# 41           4.5         2.3          1.3         0.3      Iris-setosa
# 22           4.6         3.6          1.0         0.2      Iris-setosa
# 3            4.6         3.1          1.5         0.2      Iris-setosa
# 6            4.6         3.4          1.4         0.3      Iris-setosa
# 47           4.6         3.2          1.4         0.2      Iris-setosa
# 2            4.7         3.2          1.3         0.2      Iris-setosa
# 29           4.7         3.2          1.6         0.2      Iris-setosa
# 12           4.8         3.0          1.4         0.1      Iris-setosa
# ...

# %%
print data.sort(columns='SepalWidth')
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 60           5.0         2.0          3.5         1.0  Iris-versicolor
# 62           6.0         2.2          4.0         1.0  Iris-versicolor
# 119          6.0         2.2          5.0         1.5   Iris-virginica
# 68           6.2         2.2          4.5         1.5  Iris-versicolor
# 41           4.5         2.3          1.3         0.3      Iris-setosa
# 53           5.5         2.3          4.0         1.3  Iris-versicolor
# 93           5.0         2.3          3.3         1.0  Iris-versicolor
# 87           6.3         2.3          4.4         1.3  Iris-versicolor
# 81           5.5         2.4          3.7         1.0  Iris-versicolor
# 80           5.5         2.4          3.8         1.1  Iris-versicolor
# 57           4.9         2.4          3.3         1.0  Iris-versicolor
# 72           6.3         2.5          4.9         1.5  Iris-versicolor
# ...

# %%
print data.sort(columns='PetalLength')
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 22          4.6         3.6          1.0         0.2      Iris-setosa
# 13          4.3         3.0          1.1         0.1      Iris-setosa
# 14          5.8         4.0          1.2         0.2      Iris-setosa
# 35          5.0         3.2          1.2         0.2      Iris-setosa
# 36          5.5         3.5          1.3         0.2      Iris-setosa
# 40          5.0         3.5          1.3         0.3      Iris-setosa
# 38          4.4         3.0          1.3         0.2      Iris-setosa
# 42          4.4         3.2          1.3         0.2      Iris-setosa
# 2           4.7         3.2          1.3         0.2      Iris-setosa
# 41          4.5         2.3          1.3         0.3      Iris-setosa
# 16          5.4         3.9          1.3         0.4      Iris-setosa
# 17          5.1         3.5          1.4         0.3      Iris-setosa
# ...

# %%
print data.sort(columns='PetalWidth')
# Out:
#     SepalLength  SepalWidth  PetalLength  PetalWidth             Name
# 32          5.2         4.1          1.5         0.1      Iris-setosa
# 13          4.3         3.0          1.1         0.1      Iris-setosa
# 37          4.9         3.1          1.5         0.1      Iris-setosa
# 9           4.9         3.1          1.5         0.1      Iris-setosa
# 12          4.8         3.0          1.4         0.1      Iris-setosa
# 34          4.9         3.1          1.5         0.1      Iris-setosa
# 0           5.1         3.5          1.4         0.2      Iris-setosa
# 27          5.2         3.5          1.5         0.2      Iris-setosa
# 28          5.2         3.4          1.4         0.2      Iris-setosa
# 29          4.7         3.2          1.6         0.2      Iris-setosa
# 30          4.8         3.1          1.6         0.2      Iris-setosa
# 33          5.5         4.2          1.4         0.2      Iris-setosa
# ...
