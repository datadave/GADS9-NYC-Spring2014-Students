# %%
import pandas as pd
import numpy as np

# %%
print 'Pandas version: ' + pd.__version__
# Out:
# Pandas version: 0.13.1

# %%
# %matplotlib inline

# %%
brewers_state = pd.read_excel('BA_work_20131.xlsx', 'Brewers by State')
brewers_state.head()
# Out:
#   State        Name  2004  2005  2006  2007  2008  2009  2010  2011  2012
# 0    AK      Alaska    12    11    15    16    16    17    20    22    21
# 1    AL     Alabama     4     5     5     6     6     6     7     7    12
# 2    AR    Arkansas     4     4     5     4     4     4     5     7    10
# 3    AZ     Arizona    33    27    28    31    31    31    31    35    46
# 4    CA  California   256   253   283   293   307   305   318   332   363
#
# [5 rows x 11 columns]

# %%
#pd.read_excel()

# %%
brewers_state.tail()
# Out:
#     State           Name  2004  2005  2006  2007  2008  2009  2010  2011  2012
# 47     WA     Washington    85    93   106   109   109   123   148   161   189
# 48     WI      Wisconsin    92    92    88    94    99   101   112   115   132
# 49     WV  West Virginia     4     4     4     4     4     6     7     5     5
# 50     WY        Wyoming    12    13    10    13    13    14    14    14    14
# 51  Total            USA  1635  1612  1741  1805  1896  1933  2131  2309  2751
#
# [5 rows x 11 columns]

# %%
states_2012 = brewers_state[['State', 2012]][:-1]
states_2012.head()
# Out:
#   State  2012
# 0    AK    21
# 1    AL    12
# 2    AR    10
# 3    AZ    46
# 4    CA   363
#
# [5 rows x 2 columns]

# %%
states_2012.plot(kind='bar', title='Breweries by State in 2012')
states_2012.plot()

# %%
brewers_ny = brewers_state['State'] == 'NY'
brewers_state[brewers_ny]
# Out:
#    State      Name  2004  2005  2006  2007  2008  2009  2010  2011  2012
# 34    NY  New York    79    73    79    75    73    76    89   101   127
#
# [1 rows x 11 columns]

# %%
brewers_time = pd.read_excel('BA_work_20131.xlsx', 'Brewers and Wholesalers', skiprows=1, index_col='YEAR')
brewers_time.head()
# Out:
#      TRADITIONAL BREWERIES SPECIALTY BREWERIES  TOTAL BREWERIES  \
# YEAR
# 1887                  2269                 NaN             2269
# 1888                  1968                 NaN             1968
# 1889                  2144                 NaN             2144
# 1890                  2156                 NaN             2156
# 1891                  2138                 NaN             2138
#
#       BEER WHOLESALERS  Unnamed: 5  Unnamed: 6 Unnamed: 7  Year  \
# YEAR
# 1887              3309         NaN         NaN     Census  1810
# 1888              3370         NaN         NaN        NaN   NaN
# 1889              3603         NaN         NaN        NaN   NaN
# 1890              3697         NaN         NaN        NaN   NaN
# 1891              5039         NaN         NaN        NaN   NaN
#
#       Count of Breweries
# YEAR
# 1887                 150
# 1888                 NaN
# 1889                 NaN
# 1890                 NaN
# 1891                 NaN
#
# ...

# %%
brewers_time['TOTAL BREWERIES'].plot(title='Breweries in the US, 1887-2012')

# %%
brewers_time.plot()
