# %%
# %matplotlib inline

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Acquire the Data

# %%
diamonds = pd.read_csv('data/diamonds.csv')

# %%
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price  x length  y width  \
# 0   0.23    Ideal     E     SI2   61.5     55    326      3.95     3.98
# 1   0.21  Premium     E     SI1   59.8     61    326      3.89     3.84
# 2   0.23     Good     E     VS1   56.9     65    327      4.05     4.07
# 3   0.29  Premium     I     VS2   62.4     58    334      4.20     4.23
# 4   0.31     Good     J     SI2   63.3     58    335      4.34     4.35
#
#   z depth
# 0    2.43
# 1    2.31
# 2    2.31
# 3    2.63
# 4    2.75
#
# [5 rows x 10 columns]

# %% [markdown]
# ## Clean the Data
#
# 1. Give the cut a score (Fair, Good, Very Good, Premium, Ideal)
# 2. Give the color a score, J (worst), I, H, G, F, E, D (best)
# 3. Give the clarity a score, I1 (worst), SI1, SI2, VS1, VS2, VVS1, VVS2, IF (best)

# %%
diamonds.color.unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
diamonds.describe()
# Out:
#               carat         depth         table         price      x length  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940     61.749405     57.457184   3932.799722      5.731157
# std        0.474011      1.432621      2.234491   3989.439738      1.121761
# min        0.200000     43.000000     43.000000    326.000000      0.000000
# 25%        0.400000     61.000000     56.000000    950.000000      4.710000
# 50%        0.700000     61.800000     57.000000   2401.000000      5.700000
# 75%        1.040000     62.500000     59.000000   5324.250000      6.540000
# max        5.010000     79.000000     95.000000  18823.000000     10.740000
#
#             y width
# count  53940.000000
# mean       5.734526
# std        1.142135
# min        0.000000
# 25%        4.720000
# 50%        5.710000
# 75%        6.540000
# max       58.900000
#
# [8 rows x 6 columns]

# %%
colorScore = []
cutScore = []
clarityScore = []
colors = ['0','J','I','H','G','F','E','D']
cuts = ['0','Fair','Good','Very Good','Premium','Ideal']
clarity = ['0','I1','SI1','SI2','VS1','VS2','VVS1','VVS2','IF']

for m in diamonds.color:
        if m in colors:
            colorScore.append(colors.index(m))
        else: colorScore.append(0)

for m in diamonds.cut:
    if m in cuts:
        cutScore.append(cuts.index(m))
    else: cutScore.append(0)
        
for m in diamonds.clarity:
    if m in clarity:
        clarityScore.append(clarity.index(m))
    else: clarityScore.append(0)
        
diamonds['colorScore']=colorScore
diamonds['cutScore']=cutScore
diamonds['clarityScore']=clarityScore
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price  x length  y width  \
# 0   0.23    Ideal     E     SI2   61.5     55    326      3.95     3.98
# 1   0.21  Premium     E     SI1   59.8     61    326      3.89     3.84
# 2   0.23     Good     E     VS1   56.9     65    327      4.05     4.07
# 3   0.29  Premium     I     VS2   62.4     58    334      4.20     4.23
# 4   0.31     Good     J     SI2   63.3     58    335      4.34     4.35
#
#   z depth  colorScore  cutScore  clarityScore
# 0    2.43           6         5             3
# 1    2.31           6         4             2
# 2    2.31           6         2             4
# 3    2.63           2         4             5
# 4    2.75           1         2             3
#
# [5 rows x 13 columns]

# %%
diamonds[['carat','price','colorScore','cutScore','clarityScore']].describe()
# Out:
#               carat         price    colorScore      cutScore  clarityScore
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean       0.797940   3932.799722      4.405803      3.904097      4.081183
# std        0.474011   3989.439738      1.701105      1.116600      1.769445
# min        0.200000    326.000000      1.000000      1.000000      1.000000
# 25%        0.400000    950.000000      3.000000      3.000000      2.000000
# 50%        0.700000   2401.000000      4.000000      4.000000      4.000000
# 75%        1.040000   5324.250000      6.000000      5.000000      5.000000
# max        5.010000  18823.000000      7.000000      5.000000      8.000000
#
# [8 rows x 5 columns]

# %%
print len(diamonds[diamonds.colorScore==0])
print len(diamonds[diamonds.cutScore==0])
print len(diamonds[diamonds.clarityScore==0])
# Out:
# 0
# 0
# 0

# %% [markdown]
# ## Visualize the Data

# %%
fig, ax1 = plt.subplots(1,1)
ax1.hist(diamonds.carat, bins=100, color='#eeeeee')
ax1.set_xlabel('Carat')
ax1.set_title('Number of Diamonds by Carat Size')
plt.show()

# %%
fig, ax1 = plt.subplots(1,1)
ax1.hist(diamonds.price, bins=100, color='#eeeeee')
ax1.set_xlabel('Price')
ax1.set_title('Cost of Diamonds')
plt.show()

# %%
fig, ax1 = plt.subplots(1,1)
ax1.hist(diamonds.cutScore, bins=5, color='#eeeeee')
ax1.set_xlabel('Cut Score')

# %%
fig, ax1 = plt.subplots(1,1)
ax1.hist(diamonds.clarityScore, bins=8, color='#eeeeee')
ax1.set_xlabel('Clarity Score')

# %%
fig, ax1 = plt.subplots(1,1)
ax1.hist(diamonds.colorScore, bins=7, color='#eeeeee')
ax1.set_xlabel('Color Score')

# %%
plt.figure(figsize=(10,5))
plt.scatter(diamonds.price, diamonds.carat, lw=0, alpha=.2)
plt.xlabel('Price')
plt.ylabel('Carat')
plt.xscale('log')
plt.title('Price vs. Carat', fontsize='x-large')

# %%
plt.figure(figsize=(10,5))
plt.scatter(diamonds.clarityScore, diamonds.price, lw=0, alpha=.05)
plt.xlabel('Price')
plt.ylabel('Clarity Score')
plt.yscale('log')
plt.title('Price vs. Clarity Score', fontsize='x-large')

# %%
diamonds['OverallScore']=diamonds.cutScore*diamonds.clarityScore*diamonds.colorScore*diamonds.carat
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price  x length  y width  \
# 0   0.23    Ideal     E     SI2   61.5     55    326      3.95     3.98
# 1   0.21  Premium     E     SI1   59.8     61    326      3.89     3.84
# 2   0.23     Good     E     VS1   56.9     65    327      4.05     4.07
# 3   0.29  Premium     I     VS2   62.4     58    334      4.20     4.23
# 4   0.31     Good     J     SI2   63.3     58    335      4.34     4.35
#
#   z depth  colorScore  cutScore  clarityScore  Overall Score  OverallScore
# 0    2.43           6         5             3          20.70         20.70
# 1    2.31           6         4             2          10.08         10.08
# 2    2.31           6         2             4          11.04         11.04
# 3    2.63           2         4             5          11.60         11.60
# 4    2.75           1         2             3           1.86          1.86
#
# [5 rows x 15 columns]

# %%
fig, ax1 = plt.subplots(1,1)
ax1.hist(diamonds.OverallScore, bins=100, color='#eeeeee')
ax1.set_xlabel('Overall Score')

# %%
plt.figure(figsize=(10,5))
plt.scatter(diamonds.price, diamonds.OverallScore, lw=0, alpha=.2)
plt.xlabel('Price')
plt.ylabel('Overall Score')
plt.xscale('log')
plt.title('Price vs. Score', fontsize='x-large')

# %%
plt.figure(figsize=(10,5))
plt.scatter(diamonds.carat, [diamonds.cutScore*diamonds.clarityScore*diamonds.colorScore], lw=0, alpha=.2)
plt.xlabel('Carat')
plt.ylabel('Score (minus Carat)')
#plt.xscale('log')
plt.title('Carat vs. Score', fontsize='x-large')

# %%
#fig = plt.figure()
#ax = fig.add_subplot(1,5,5)
fig, ax = plt.subplots(1, 5, figsize=(16,4), tight_layout=True)

ax[0].hist(diamonds.price, bins=100, histtype='stepfilled', normed=True, color='r', alpha=.2, ec='none')
ax[0].set_xlabel('Price')
ax[1].hist(diamonds.carat, bins=100, histtype='stepfilled', ec='none', normed=True, color='#cccccc', zorder=0)
ax[1].set_xlabel('Carat')
ax[2].hist(diamonds.clarityScore, bins=8, histtype='stepfilled', ec='none', normed=True, color='#cccccc', zorder=0)
ax[2].set_xlabel('Clarity Score')
ax[3].hist(diamonds.colorScore, bins=7, histtype='stepfilled', ec='none', normed=True, color='#cccccc', zorder=0)
ax[3].set_xlabel('Color Score')
ax[4].hist(diamonds.cutScore, bins=5, histtype='stepfilled', ec='none', normed=True, color='#cccccc', zorder=0)
ax[4].set_xlabel('Cut Score')
